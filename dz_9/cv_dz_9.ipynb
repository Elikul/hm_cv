# %%
# Монтирование Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics easyocr roboflow
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.149-py3-none-any.whl.metadata (37 kB)
# Collecting easyocr
#   Downloading easyocr-1.7.2-py3-none-any.whl.metadata (10 kB)
# Collecting roboflow
#   Downloading roboflow-1.1.65-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.11/dist-packages (from easyocr) (4.11.0.86)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (from easyocr) (0.25.2)
# Collecting python-bidi (from easyocr)
#   Downloading python_bidi-0.6.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.11/dist-packages (from easyocr) (2.1.1)
# Collecting pyclipper (from easyocr)
#   Downloading pyclipper-1.3.0.post6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Collecting ninja (from easyocr)
#   Downloading ninja-1.11.1.4-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from roboflow) (2025.4.26)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /usr/local/lib/python3.11/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.4.8)
# Collecting opencv-python-headless (from easyocr)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting pillow-heif>=0.18.0 (from roboflow)
#   Downloading pillow_heif-0.22.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.9.0.post0)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.4.0)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.0.0)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.58.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image->easyocr) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image->easyocr) (2025.5.26)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image->easyocr) (0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.149-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 32.8 MB/s eta 0:00:00
# Downloading easyocr-1.7.2-py3-none-any.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 95.8 MB/s eta 0:00:00
# Downloading roboflow-1.1.65-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.8/85.8 kB 8.7 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.8 MB/s eta 0:00:00
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 22.3 MB/s eta 0:00:00
# Downloading pillow_heif-0.22.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 126.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 89.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 72.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 53.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.3 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 17.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 107.4 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading ninja-1.11.1.4-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (422 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.8/422.8 kB 36.1 MB/s eta 0:00:00
# Downloading pyclipper-1.3.0.post6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (969 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 969.6/969.6 kB 54.4 MB/s eta 0:00:00
# Downloading python_bidi-0.6.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (292 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.9/292.9 kB 26.8 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Installing collected packages: python-bidi, pyclipper, filetype, python-dotenv, pillow-heif, opencv-python-headless, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, ninja, idna, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, roboflow, ultralytics-thop, ultralytics, easyocr
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed easyocr-1.7.2 filetype-1.2.0 idna-3.7 ninja-1.11.1.4 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 opencv-python-headless-4.10.0.84 pillow-heif-0.22.0 pyclipper-1.3.0.post6 python-bidi-0.6.6 python-dotenv-1.1.0 roboflow-1.1.65 ultralytics-8.3.149 ultralytics-thop-2.0.14

# %%
import cv2
import time
import numpy as np
import pandas as pd
from ultralytics import YOLO
from IPython.display import HTML
from base64 import b64encode
import easyocr
from roboflow import Roboflow
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# # Детекция и трекинг машин
#
# Основные задачи:
#
#  * Детекция и трекинг автомобилей :
#     - Использование модели YOLOv8 для распознавания автомобилей.
#     - Применение трекера BoT-SORT для отслеживания уникальных ID объектов.
#     - Подсчет количества машин, пересекающих контрольную линию слева направо и
#       справа налево.
#  * Распознавание автомобильных номеров :
#    - Обнаружение номерных табличек на автомобилях с помощью обученной модели
#      YOLOv8.
#    - Улучшение качества изображения номерных табличек с использованием методов
#      обработки изображений.
#    - Распознавание текста на номерных табличках с помощью библиотеки EasyOCR.
#  * Визуализация результатов :
#    - Создание тепловой карты плотности движения автомобилей.
#    - Отображение bounding boxes с ID и классами объектов.
#    - Сохранение обработанного видео с наложенными результатами.

# %% [markdown]
# ## Данные
# Для анализа предоставлены два видеофайла:
#
# * Видео 1: [camera_uglich_shot.mp4](https://drive.google.com/file/d/1LSNU7ZAjZB1dnfrawOgSD_WLUJRz7BkM/view?usp=sharing) (дорога в Угличе, длительность 15 секунд).
# * Видео 2: [camera_moscow.mp4](https://drive.google.com/file/d/1xqCXMk0p71EkpY9nbawiZwKJXUoG0Y4Q/view?usp=sharing) (дорога в Москве, длительность 17 секунд).
#
# Оба видео содержат движение автомобилей по дорогам. Качество видео довольно среднее и детали, такие как автомобильные номера, практически не различимы. (ничего лучше найти и записать я не нашла)

# %% [markdown]
# ### 1. Загрузка данных и инициализация

# %%
# Путь к основной папке
base_path = '/content/drive/MyDrive/Tracking'

# Путь к исходному видео
original_video_path = f'{base_path}/camera_uglich_shot.mp4'

# Путь к обработанному видео
tracked_video_path = f'{base_path}/tracked_video_uglich.mp4'

# Путь к файлу с результатами обнаруженных автомобильных номеров
csv_output_path = f'{base_path}/detected_plates_uglich.csv'

# %%
def display_video(file_path):
    mp4 = open(file_path, 'rb').read()
    data_url = 'data:video/mp4;base64,' + b64encode(mp4).decode()
    return HTML(f"""
    <video width="640" height="320" controls>
        <source src="{data_url}" type="video/mp4">
    </video>
    """)

# %%
# Отображение оригинального видео
display_video(original_video_path)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ### 2. Обнаружение и распознавание номерных табличек
#
# * Номерные таблички обнаруживаются с помощью обученной модели YOLOv8. Так как  предобученная модель может распозновать только машины, то нужно было дообучить на данных с размеченными автомобильными номера (https://universe.roboflow.com/roboflow-universe-projects/license-plate-recognition-rxg4e), для распознования плашки.
# * Изображение таблички обрабатывается для улучшения качества (преобразование в градации серого, пороговая обработка, размытие).
# * Текст на табличке распознается с помощью библиотеки EasyOCR.

# %%
rf = Roboflow(api_key="5pXFfA6Z3uRGVkNdeUMD")
project = rf.workspace("roboflow-universe-projects").project("license-plate-recognition-rxg4e")
version = project.version(6)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in License-Plate-Recognition-6 to yolov8:: 100%|██████████| 323175/323175 [00:20<00:00, 15900.26it/s]
# Extracting Dataset Version Zip to License-Plate-Recognition-6 in yolov8:: 100%|██████████| 20262/20262 [00:02<00:00, 8061.84it/s]

# %%
# Обучение модели для распознования автомобильных номеров
model_plates = YOLO('yolov8n.pt')
results = model_plates.train(data=f"{dataset.location}/data.yaml",
                             epochs=10,
                             imgsz=640,
                             device='cuda')

# %%
# Обнаружение номерной таблички
# Возвращает координаты bounding box
def detect_license_plate(image, model_plates):
    # Используем модель для предсказания
    results = model_plates(image)

    # Получаем координаты bounding box'а
    for result in results:
        boxes = result.boxes.data.tolist()
        for box in boxes:
            x1, y1, x2, y2, score, class_id = box
            # Предполагаем, что класс 0 - это номерная табличка
            if int(class_id) == 0:
                return int(x1), int(y1), int(x2), int(y2), score

    return None

# Обрезка и улучшение качества изображения номерной таблички
def preprocess_license_plate(image, bbox):
    x1, y1, x2, y2 = bbox

    # Обрезка изображения по координатам bounding box'а
    plate_image = image[y1:y2, x1:x2]

    # Преобразование в градации серого
    gray = cv2.cvtColor(plate_image, cv2.COLOR_BGR2GRAY)

    # Повышение контраста с помощью адаптивного порога
    _, thresholded = cv2.threshold(gray, 64, 255, cv2.THRESH_BINARY_INV)

    # Улучшение качества с помощью размытия
    blurred = cv2.GaussianBlur(thresholded, (3, 3), 0)

    return blurred

# Распознавание текста с помощью EasyOCR
def recognize_text(image):
    # Инициализация OCR
    reader = easyocr.Reader(['ru'], gpu=True)
    results = reader.readtext(image)

    # Обработка результатов
    for detection in results:
        bbox, text, score = detection
        # Очистка текста
        text = text.upper().replace(' ', '')
        return text, score

    return None, None

# %%
# Полный пайплайн обработки изображения
# 1. Обнаружение номерной таблички
# 2. Улучшение качества изображения
# 3. Распознавание текста
def pipline_image(image,
                  yolo_weights_path=f'{base_path}/runs/detect/train/weights/best.pt'):
    # Загрузка обученной модели YOLOv8
    model_plates = YOLO(yolo_weights_path)

    # Обнаружение номерной таблички
    bbox = detect_license_plate(image, model_plates)
    if bbox is None:
        print("\nНомерная табличка не найдена\n")
        return

    x1, y1, x2, y2, score = bbox
    print(f"\nНомерная табличка найдена с координатами: ({x1}, {y1}, {x2}, {y2}), уверенность: {score:.3f}\n")

    # Улучшение качества изображения
    processed_image = preprocess_license_plate(image, (x1, y1, x2, y2))

    # Сохранение обработанного изображения для проверки
    # cv2.imwrite('processed_plate.jpg', processed_image)
    # print("\nОбработанное изображение номерной таблички сохранено\n")

    # Шаг 3: Распознавание текста
    text, text_score = recognize_text(processed_image)
    if text is not None:
        print(f"\nРаспознанный текст: {text}, уверенность: {text_score:.3f}\n")
        return text, text_score
    else:
        print("\nТекст не распознан\n")
        return None

# %% [markdown]
# ### 3. Детекция автомобилей :
# * Используется предобученная модель YOLOv8 для распознавания автомобилей (класс car - 2).
# * Для каждого автомобиля определяется bounding box, центр его координат и уникальный ID с помощью трекера BoT-SORT.

# %%
# Загрузка предобученной модели YOLOv8
model_cars = YOLO('yolov8n.pt')

# %%
tracker_config = 'botsort.yaml'
object_states = {}
crossing_count_left_to_right = 0
crossing_count_right_to_left = 0
detected_plates = []
heatmap = None

# %%
# Инициализация параметров видео
def initialize_video(original_video_path):
    cap = cv2.VideoCapture(original_video_path)
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    return cap, frame_width, frame_height, fps

# Инициализация видеозаписи
def initialize_output_video(tracked_video_path,
                            fps,
                            frame_width,
                            frame_height):
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(tracked_video_path, fourcc, fps, (frame_width, frame_height))
    return out

# %% [markdown]
# ### 4. Подсчет пересечений контрольной линии :
# * На видео наносится горизонтальная линия, которая служит границей для подсчета автомобилей.
# * При пересечении линии слева направо или справа налево увеличивается соответствующий счётчик.

# %%
# Создание линии подсчета
def define_count_line(frame_width, frame_height):
    y = int(frame_height - frame_height * 0.4)
    line_start = (0, y)
    line_end = (frame_width, y)
    return line_start, line_end

# %% [markdown]
# ### 5. Создание тепловой карты
#
# * Для каждого автомобиля на тепловой карте рисуется гауссиана в месте его центра.
# * Тепловая карта накладывается на исходное видео для визуализации плотности движения.

# %%
# Инициализация тепловой карты
def initialize_heatmap(frame_height, frame_width):
    return np.zeros((frame_height, frame_width), dtype=np.float32)


# Рисование гауссианы в тепловой карте
def draw_gaussian_heatpoint(heatmap,
                            center,
                            radius=30,
                            strength=1.0):
    x, y = center
    size = int(radius * 2 + 1)
    gaussian = cv2.getGaussianKernel(size, radius / 3, ktype=cv2.CV_32F)
    kernel = np.outer(gaussian, gaussian.T)
    kernel = kernel / kernel.max() * strength

    height, width = heatmap.shape[:2]
    x0, y0 = max(0, x - radius), max(0, y - radius)
    x1, y1 = min(width, x + radius + 1), min(height, y + radius + 1)

    kernel_x0 = max(0, radius - x)
    kernel_y0 = max(0, radius - y)
    kernel_x1 = kernel_x0 + x1 - x0
    kernel_y1 = kernel_y0 + y1 - y0

    if x0 >= width or y0 >= height or x1 <= 0 or y1 <= 0:
        return

    heatmap[y0:y1, x0:x1] += kernel[kernel_y0:kernel_y1, kernel_x0:kernel_x1]

# Наложение тепловой карты
def apply_heatmap_overlay(frame, heatmap):
    heatmap_normalized = cv2.normalize(heatmap,
                                       None,
                                       0,
                                       255,
                                       cv2.NORM_MINMAX)
    heatmap_colored = cv2.applyColorMap(heatmap_normalized.astype(np.uint8),
                                        cv2.COLORMAP_JET)

    if heatmap_colored.shape[:2] != frame.shape[:2]:
        heatmap_colored = cv2.resize(heatmap_colored,
                                     (frame.shape[1], frame.shape[0]))

    alpha = 0.3
    return cv2.addWeighted(frame,
                           1 - alpha,
                           heatmap_colored,
                           alpha,
                           0)

# %%
# Обработка треков объектов
def process_tracks(model_cars,
                   frame,
                   line_start,
                   line_end,
                   pipeline_image):
    global crossing_count_left_to_right, crossing_count_right_to_left, object_states, heatmap

    results = model_cars.track(frame,
                               persist=True,
                               tracker=tracker_config,
                               classes=[2])

    for result in results:
        boxes = result.boxes.cpu().numpy()
        track_ids = boxes.id.astype(int) if boxes.id is not None else []

        for box, track_id in zip(boxes, track_ids):
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            cx, cy = (x1 + x2) // 2, (y1 + y2) // 2

            # Обновление тепловой карты
            draw_gaussian_heatpoint(heatmap, (cx, cy), strength=10)

            # Инициализация состояния объекта
            if track_id not in object_states:
                object_states[track_id] = {
                    'above_line': cy < line_start[1],
                    'counted_left_to_right': False,
                    'counted_right_to_left': False
                }

            prev_above_line = object_states[track_id]['above_line']
            current_above_line = cy < line_start[1]

            # Лево -> Право
            if prev_above_line and not current_above_line and not object_states[track_id]['counted_left_to_right']:
                crossing_count_left_to_right += 1
                object_states[track_id]['counted_left_to_right'] = True

            # Право -> Лево
            if not prev_above_line and current_above_line and not object_states[track_id]['counted_right_to_left']:
                crossing_count_right_to_left += 1
                object_states[track_id]['counted_right_to_left'] = True

            object_states[track_id]['above_line'] = current_above_line

            # Распознавание номеров
            cropped_plate = frame[y1:y2, x1:x2]
            ocr_results = pipeline_image(cropped_plate)

            plate_text = ""
            if ocr_results:
                text, confidence = ocr_results
                if confidence > 0.5:
                    plate_text = text

            # Логирование распознанного номера
            if plate_text:
                timestamp = time.strftime('%H:%M:%S', time.gmtime(cv2.CAP_PROP_POS_MSEC))
                detected_plates.append({
                    'timestamp': timestamp,
                    'track_id': track_id,
                    'plate': plate_text
                })

            # Отрисовка
            color = (0, 0, 255) if (object_states[track_id]['counted_left_to_right'] or
                                    object_states[track_id]['counted_right_to_left']) else (255, 0, 0)
            cv2.rectangle(frame,
                          (x1, y1),
                          (x2, y2),
                          color,
                          2)
            cv2.putText(frame,
                        f'ID: {track_id}',
                        (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX,
                        0.9,
                        color,
                        2)
            cv2.circle(frame,
                       (cx, cy),
                       5,
                       color,
                       -1)

            if plate_text:
                cv2.putText(frame,
                            f'Plate: {plate_text}',
                            (x1, y1 - 30),
                            cv2.FONT_HERSHEY_SIMPLEX,
                            0.7,
                            (31, 43, 61),
                            2)

    return frame

# %% [markdown]
# ### 6. Сохранение результатов
# * Обработанное видео сохраняется с bounding boxes, тепловой картой и счетчиками.
# * Результаты распознавания номерных табличек сохраняются в CSV-файл.

# %%
# Вывод счетчиков движения
def draw_crossing_counters(frame,
                           left_to_right,
                           right_to_left):
    cv2.putText(frame,
                f'Right to Left: {right_to_left}',
                (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX,
                1,
                (10, 38, 165),
                2)
    cv2.putText(frame,
                f'Left to Right: {left_to_right}',
                (10, 70),
                cv2.FONT_HERSHEY_SIMPLEX,
                1,
                (10, 38, 165),
                2)
    return frame


# Сохранение результатов
def save_results(detected_plates,
                 base_path, tracked_video_path,
                 csv_output_path=f'{base_path}/detected_plates.csv'):
    df = pd.DataFrame(detected_plates)
    df.to_csv(csv_output_path, index=False)
    print(f'Логи распознанных номеров сохранены по пути: {csv_output_path}')
    print(f'Видео с тепловой картой и номерами сохранено по пути: {tracked_video_path}')

# %%
# Основной цикл обработки кадров
def run_tracking_pipeline(original_video_path,
                          tracked_video_path,
                          base_path,
                          model_cars,
                          pipeline_image,
                          csv_output_path):
    global heatmap

    cap, frame_width, frame_height, fps = initialize_video(original_video_path)
    line_start, line_end = define_count_line(frame_width, frame_height)
    out = initialize_output_video(tracked_video_path,
                                  fps,
                                  frame_width,
                                  frame_height)
    heatmap = initialize_heatmap(frame_height, frame_width)

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Рисуем линию подсчёта
        cv2.line(frame, line_start, line_end, (255, 0, 139), 2)

        # Обрабатываем треки
        processed_frame = process_tracks(model_cars,
                                         frame,
                                         line_start,
                                         line_end,
                                         pipeline_image)

        # Накладываем тепловую карту
        final_frame = apply_heatmap_overlay(processed_frame, heatmap)

        # Отображаем счётчики
        final_frame = draw_crossing_counters(final_frame,
                                             crossing_count_left_to_right,
                                             crossing_count_right_to_left)

        # Запись кадра
        out.write(final_frame)

    # Освобождение ресурсов
    cap.release()
    out.release()

    # Сохраняем CSV
    save_results(detected_plates,
                 base_path,
                 tracked_video_path,
                 csv_output_path)

# %% [markdown]
# ### 7. Тестирование

# %%
run_tracking_pipeline(
    original_video_path=original_video_path,
    tracked_video_path=tracked_video_path,
    base_path=base_path,
    model_cars=model_cars,
    pipeline_image=pipline_image,  # OCR-модель
    csv_output_path=csv_output_path
)
# Out:
# requirements: Ultralytics requirement ['lap>=0.5.12'] not found, attempting AutoUpdate...
#
# requirements: AutoUpdate success ✅ 0.7s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# 0: 288x640 1 car, 51.1ms
# Speed: 15.9ms preprocess, 51.1ms inference, 404.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 352x640 (no detections), 36.0ms
# Speed: 1.5ms preprocess, 36.0ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 1 car, 7.2ms
# Speed: 2.9ms preprocess, 7.2ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 352x640 (no detections), 9.3ms
# Speed: 1.7ms preprocess, 9.3ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 1 car, 7.6ms
# Speed: 2.0ms preprocess, 7.6ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 352x640 (no detections), 13.5ms
# Speed: 2.1ms preprocess, 13.5ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 1 car, 8.4ms
# Speed: 2.5ms preprocess, 8.4ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 352x640 (no detections), 7.3ms
# Speed: 1.5ms preprocess, 7.3ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 1 car, 11.0ms
# Speed: 3.5ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 352x640 (no detections), 8.5ms
# Speed: 1.4ms preprocess, 8.5ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 1 car, 9.6ms
# Speed: 2.5ms preprocess, 9.6ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 384x640 (no detections), 37.1ms
# Speed: 1.6ms preprocess, 37.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 1 car, 7.9ms
# Speed: 2.8ms preprocess, 7.9ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 384x640 (no detections), 7.1ms
# Speed: 1.6ms preprocess, 7.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 1 car, 21.6ms
# Speed: 2.8ms preprocess, 21.6ms inference, 2.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 384x640 1 License_Plate, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# WARNING:easyocr.easyocr:Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Номерная табличка найдена с координатами: (1, 1, 184, 103), уверенность: 0.332
#
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# WARNING:easyocr.easyocr:Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Выходные данные были обрезаны до нескольких последних строк (5000).
#
# 0: 320x640 1 License_Plate, 7.3ms
# Speed: 6.1ms preprocess, 7.3ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# Номерная табличка найдена с координатами: (1, 5, 315, 149), уверенность: 0.813
#
#
# Текст не распознан
#
#
# 0: 288x640 2 cars, 9.9ms
# Speed: 2.9ms preprocess, 9.9ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 416x640 1 License_Plate, 7.0ms
# Speed: 1.6ms preprocess, 7.0ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка найдена с координатами: (62, 43, 86, 51), уверенность: 0.590
#
#
# Текст не распознан
#
#
# 0: 320x640 1 License_Plate, 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# Номерная табличка найдена с координатами: (2, 6, 314, 147), уверенность: 0.847
#
#
# Текст не распознан
#
#
# 0: 288x640 2 cars, 10.1ms
# Speed: 4.7ms preprocess, 10.1ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 448x640 1 License_Plate, 7.7ms
# Speed: 1.7ms preprocess, 7.7ms inference, 1.9ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка найдена с координатами: (62, 44, 84, 52), уверенность: 0.615
#
#
# Текст не распознан
#
#
# 0: 320x640 1 License_Plate, 7.8ms
# Speed: 2.0ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# Номерная табличка найдена с координатами: (2, 5, 304, 145), уверенность: 0.820
#
#
# Текст не распознан
#
#
# 0: 288x640 2 cars, 14.6ms
# Speed: 2.8ms preprocess, 14.6ms inference, 2.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 448x640 1 License_Plate, 6.7ms
# Speed: 1.7ms preprocess, 6.7ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка найдена с координатами: (64, 45, 87, 54), уверенность: 0.533
#
#
# Текст не распознан
#
#
# 0: 320x640 2 License_Plates, 15.7ms
# Speed: 2.0ms preprocess, 15.7ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# Номерная табличка найдена с координатами: (2, 6, 299, 143), уверенность: 0.752
#
#
# Текст не распознан
#
#
# 0: 288x640 2 cars, 13.0ms
# Speed: 2.8ms preprocess, 13.0ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 416x640 1 License_Plate, 7.9ms
# Speed: 2.3ms preprocess, 7.9ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка найдена с координатами: (62, 44, 84, 52), уверенность: 0.488
#
#
# Текст не распознан
#
#
# 0: 320x640 1 License_Plate, 8.3ms
# Speed: 2.3ms preprocess, 8.3ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# Номерная табличка найдена с координатами: (2, 7, 289, 142), уверенность: 0.743
#
#
# Текст не распознан
#
#
# 0: 288x640 2 cars, 10.7ms
# Speed: 7.8ms preprocess, 10.7ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 448x640 1 License_Plate, 6.7ms
# Speed: 1.6ms preprocess, 6.7ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка найдена с координатами: (59, 46, 82, 54), уверенность: 0.591
#
#
# Текст не распознан
#
#
# 0: 320x640 3 License_Plates, 8.4ms
# Speed: 1.7ms preprocess, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# Номерная табличка найдена с координатами: (2, 0, 284, 74), уверенность: 0.577
#
#
# Текст не распознан
#
#
# 0: 288x640 2 cars, 10.4ms
# Speed: 4.5ms preprocess, 10.4ms inference, 2.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 480x640 1 License_Plate, 7.3ms
# Speed: 2.6ms preprocess, 7.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка найдена с координатами: (57, 47, 78, 55), уверенность: 0.522
#
#
# Текст не распознан
#
#
# 0: 320x640 1 License_Plate, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# Номерная табличка найдена с координатами: (1, 2, 280, 79), уверенность: 0.688
#
#
# Текст не распознан
#
#
# 0: 288x640 2 cars, 18.2ms
# Speed: 8.2ms preprocess, 18.2ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 480x640 1 License_Plate, 7.1ms
# Speed: 1.7ms preprocess, 7.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка найдена с координатами: (57, 48, 78, 55), уверенность: 0.527
#
#
# Текст не распознан
#
#
# 0: 320x640 1 License_Plate, 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# Номерная табличка найдена с координатами: (1, 5, 278, 85), уверенность: 0.592
#
#
# Текст не распознан
#
#
# 0: 288x640 2 cars, 14.4ms
# Speed: 2.8ms preprocess, 14.4ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 480x640 1 License_Plate, 8.6ms
# Speed: 2.5ms preprocess, 8.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка найдена с координатами: (53, 44, 74, 51), уверенность: 0.654
#
#
# Текст не распознан
#
#
# 0: 352x640 1 License_Plate, 9.9ms
# Speed: 1.7ms preprocess, 9.9ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка найдена с координатами: (1, 5, 268, 85), уверенность: 0.831
#
#
# Текст не распознан
#
#
# 0: 288x640 2 cars, 10.1ms
# Speed: 9.9ms preprocess, 10.1ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 480x640 1 License_Plate, 6.8ms
# Speed: 1.8ms preprocess, 6.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка найдена с координатами: (51, 44, 73, 52), уверенность: 0.648
#
#
# Текст не распознан
#
#
# 0: 352x640 1 License_Plate, 7.1ms
# Speed: 1.4ms preprocess, 7.1ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка найдена с координатами: (1, 6, 260, 92), уверенность: 0.831
#
#
# Текст не распознан
#
#
# 0: 288x640 2 cars, 12.9ms
# Speed: 2.7ms preprocess, 12.9ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 480x640 1 License_Plate, 8.7ms
# Speed: 2.4ms preprocess, 8.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка найдена с координатами: (48, 42, 69, 50), уверенность: 0.533
#
#
# Текст не распознан
#
#
# 0: 352x640 1 License_Plate, 7.4ms
# Speed: 1.5ms preprocess, 7.4ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка найдена с координатами: (1, 7, 249, 121), уверенность: 0.843
#
#
# Текст не распознан
#
#
# 0: 288x640 2 cars, 10.5ms
# Speed: 4.7ms preprocess, 10.5ms inference, 2.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 480x640 1 License_Plate, 6.9ms
# Speed: 1.7ms preprocess, 6.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка найдена с координатами: (45, 41, 67, 49), уверенность: 0.515
#
#
# Текст не распознан
#
#
# 0: 352x640 1 License_Plate, 7.4ms
# Speed: 2.3ms preprocess, 7.4ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка найдена с координатами: (0, 6, 242, 106), уверенность: 0.867
#
#
# Текст не распознан
#
#
# 0: 288x640 2 cars, 10.0ms
# Speed: 6.3ms preprocess, 10.0ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 480x640 (no detections), 7.1ms
# Speed: 1.7ms preprocess, 7.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 352x640 1 License_Plate, 7.2ms
# Speed: 1.7ms preprocess, 7.2ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка найдена с координатами: (1, 5, 238, 102), уверенность: 0.895
#
#
# Текст не распознан
#
#
# 0: 288x640 2 cars, 10.3ms
# Speed: 4.9ms preprocess, 10.3ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 480x640 (no detections), 9.8ms
# Speed: 2.4ms preprocess, 9.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 352x640 1 License_Plate, 7.2ms
# Speed: 1.8ms preprocess, 7.2ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка найдена с координатами: (1, 4, 237, 102), уверенность: 0.889
#
#
# Текст не распознан
#
#
# 0: 288x640 2 cars, 33.0ms
# Speed: 2.7ms preprocess, 33.0ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 512x640 1 License_Plate, 6.8ms
# Speed: 1.8ms preprocess, 6.8ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка найдена с координатами: (36, 37, 57, 47), уверенность: 0.490
#
#
# Текст не распознан
#
#
# 0: 352x640 1 License_Plate, 9.7ms
# Speed: 1.7ms preprocess, 9.7ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка найдена с координатами: (0, 3, 235, 109), уверенность: 0.876
#
#
# Текст не распознан
#
#
# 0: 288x640 2 cars, 14.9ms
# Speed: 4.5ms preprocess, 14.9ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 512x640 (no detections), 9.8ms
# Speed: 2.8ms preprocess, 9.8ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 352x640 1 License_Plate, 7.2ms
# Speed: 1.4ms preprocess, 7.2ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка найдена с координатами: (0, 4, 230, 110), уверенность: 0.924
#
#
# Текст не распознан
#
#
# 0: 288x640 2 cars, 13.6ms
# Speed: 2.7ms preprocess, 13.6ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 512x640 (no detections), 11.0ms
# Speed: 2.7ms preprocess, 11.0ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 352x640 1 License_Plate, 10.0ms
# Speed: 7.2ms preprocess, 10.0ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка найдена с координатами: (1, 4, 227, 113), уверенность: 0.931
#
#
# Текст не распознан
#
#
# 0: 288x640 2 cars, 10.2ms
# Speed: 2.8ms preprocess, 10.2ms inference, 2.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 544x640 (no detections), 7.8ms
# Speed: 2.0ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 352x640 1 License_Plate, 7.2ms
# Speed: 1.9ms preprocess, 7.2ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка найдена с координатами: (0, 3, 223, 104), уверенность: 0.895
#
#
# Текст не распознан
#
#
# 0: 288x640 3 cars, 12.4ms
# Speed: 3.7ms preprocess, 12.4ms inference, 2.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 544x640 1 License_Plate, 9.0ms
# Speed: 2.1ms preprocess, 9.0ms inference, 1.5ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка найдена с координатами: (25, 35, 46, 43), уверенность: 0.348
#
#
# Текст не распознан
#
#
# 0: 352x640 1 License_Plate, 7.6ms
# Speed: 1.6ms preprocess, 7.6ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка найдена с координатами: (0, 5, 212, 105), уверенность: 0.887
#
#
# Текст не распознан
#
#
# 0: 416x640 (no detections), 13.5ms
# Speed: 4.3ms preprocess, 13.5ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 3 cars, 17.6ms
# Speed: 2.6ms preprocess, 17.6ms inference, 2.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 448x640 (no detections), 11.1ms
# Speed: 2.5ms preprocess, 11.1ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 320x640 1 License_Plate, 12.0ms
# Speed: 1.7ms preprocess, 12.0ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# Номерная табличка найдена с координатами: (1, 5, 213, 103), уверенность: 0.764
#
#
# Текст не распознан
#
#
# 0: 416x640 (no detections), 6.9ms
# Speed: 1.9ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 3 cars, 10.1ms
# Speed: 7.4ms preprocess, 10.1ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 448x640 1 License_Plate, 6.7ms
# Speed: 1.8ms preprocess, 6.7ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка найдена с координатами: (33, 32, 52, 38), уверенность: 0.617
#
#
# Текст не распознан
#
#
# 0: 352x640 1 License_Plate, 7.1ms
# Speed: 1.5ms preprocess, 7.1ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка найдена с координатами: (0, 5, 207, 102), уверенность: 0.862
#
#
# Текст не распознан
#
#
# 0: 416x640 (no detections), 9.0ms
# Speed: 2.2ms preprocess, 9.0ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 3 cars, 10.1ms
# Speed: 2.8ms preprocess, 10.1ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 448x640 1 License_Plate, 8.5ms
# Speed: 1.9ms preprocess, 8.5ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка найдена с координатами: (33, 32, 52, 38), уверенность: 0.602
#
#
# Текст не распознан
#
#
# 0: 352x640 1 License_Plate, 20.5ms
# Speed: 2.2ms preprocess, 20.5ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка найдена с координатами: (0, 5, 205, 103), уверенность: 0.878
#
#
# Текст не распознан
#
#
# 0: 416x640 (no detections), 11.7ms
# Speed: 2.4ms preprocess, 11.7ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 11.1ms
# Speed: 4.0ms preprocess, 11.1ms inference, 2.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 352x640 1 License_Plate, 8.9ms
# Speed: 1.6ms preprocess, 8.9ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка найдена с координатами: (0, 5, 203, 104), уверенность: 0.832
#
#
# Текст не распознан
#
#
# 0: 416x640 (no detections), 9.2ms
# Speed: 2.3ms preprocess, 9.2ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 10.2ms
# Speed: 2.7ms preprocess, 10.2ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 352x640 1 License_Plate, 7.5ms
# Speed: 1.5ms preprocess, 7.5ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка найдена с координатами: (0, 6, 196, 103), уверенность: 0.767
#
#
# Текст не распознан
#
#
# 0: 448x640 (no detections), 7.9ms
# Speed: 2.1ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 10.9ms
# Speed: 6.5ms preprocess, 10.9ms inference, 3.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 352x640 1 License_Plate, 8.4ms
# Speed: 1.7ms preprocess, 8.4ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка найдена с координатами: (0, 2, 196, 101), уверенность: 0.649
#
#
# Текст не распознан
#
#
# 0: 448x640 (no detections), 6.8ms
# Speed: 1.6ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 21.3ms
# Speed: 2.7ms preprocess, 21.3ms inference, 2.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 384x640 1 License_Plate, 13.9ms
# Speed: 5.0ms preprocess, 13.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# Номерная табличка найдена с координатами: (0, 8, 193, 103), уверенность: 0.843
#
#
# Текст не распознан
#
#
# 0: 448x640 (no detections), 6.7ms
# Speed: 1.9ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 9.4ms
# Speed: 2.7ms preprocess, 9.4ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 384x640 1 License_Plate, 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# Номерная табличка найдена с координатами: (0, 5, 192, 101), уверенность: 0.782
#
#
# Текст не распознан
#
#
# 0: 448x640 (no detections), 7.0ms
# Speed: 1.7ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 10.3ms
# Speed: 3.1ms preprocess, 10.3ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 384x640 1 License_Plate, 9.7ms
# Speed: 2.4ms preprocess, 9.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# Номерная табличка найдена с координатами: (2, 0, 185, 103), уверенность: 0.844
#
#
# Распознанный текст: 5, уверенность: 0.770
#
#
# 0: 448x640 (no detections), 7.2ms
# Speed: 1.7ms preprocess, 7.2ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 10.5ms
# Speed: 4.1ms preprocess, 10.5ms inference, 2.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 384x640 1 License_Plate, 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# Номерная табличка найдена с координатами: (0, 3, 183, 98), уверенность: 0.853
#
#
# Распознанный текст: "5, уверенность: 0.085
#
#
# 0: 448x640 (no detections), 8.3ms
# Speed: 2.6ms preprocess, 8.3ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 9.8ms
# Speed: 2.8ms preprocess, 9.8ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 384x640 1 License_Plate, 9.1ms
# Speed: 2.4ms preprocess, 9.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# Номерная табличка найдена с координатами: (0, 5, 181, 95), уверенность: 0.776
#
#
# Распознанный текст: Ш;, уверенность: 0.123
#
#
# 0: 448x640 (no detections), 10.0ms
# Speed: 1.9ms preprocess, 10.0ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 10.2ms
# Speed: 3.2ms preprocess, 10.2ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 384x640 1 License_Plate, 7.1ms
# Speed: 1.5ms preprocess, 7.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# Номерная табличка найдена с координатами: (0, 2, 168, 95), уверенность: 0.820
#
#
# Текст не распознан
#
#
# 0: 448x640 (no detections), 6.9ms
# Speed: 1.6ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 14.8ms
# Speed: 5.3ms preprocess, 14.8ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 384x640 1 License_Plate, 9.4ms
# Speed: 1.7ms preprocess, 9.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# Номерная табличка найдена с координатами: (0, 2, 161, 92), уверенность: 0.708
#
#
# Распознанный текст: Ш?, уверенность: 0.233
#
#
# 0: 448x640 (no detections), 11.9ms
# Speed: 2.2ms preprocess, 11.9ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 10.2ms
# Speed: 2.4ms preprocess, 10.2ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 416x640 1 License_Plate, 9.0ms
# Speed: 1.7ms preprocess, 9.0ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка найдена с координатами: (0, 0, 151, 96), уверенность: 0.738
#
#
# Текст не распознан
#
#
# 0: 480x640 (no detections), 8.5ms
# Speed: 2.5ms preprocess, 8.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 10.4ms
# Speed: 4.7ms preprocess, 10.4ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 416x640 1 License_Plate, 7.1ms
# Speed: 1.6ms preprocess, 7.1ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка найдена с координатами: (1, 1, 154, 94), уверенность: 0.764
#
#
# Распознанный текст: ", уверенность: 0.155
#
#
# 0: 448x640 (no detections), 8.8ms
# Speed: 2.6ms preprocess, 8.8ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 10.3ms
# Speed: 2.6ms preprocess, 10.3ms inference, 2.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 416x640 1 License_Plate, 9.9ms
# Speed: 1.8ms preprocess, 9.9ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка найдена с координатами: (0, 2, 161, 95), уверенность: 0.780
#
#
# Текст не распознан
#
#
# 0: 448x640 (no detections), 7.0ms
# Speed: 2.1ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 10.0ms
# Speed: 2.6ms preprocess, 10.0ms inference, 2.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 416x640 1 License_Plate, 7.3ms
# Speed: 1.7ms preprocess, 7.3ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка найдена с координатами: (0, 0, 151, 96), уверенность: 0.608
#
#
# Текст не распознан
#
#
# 0: 448x640 (no detections), 7.0ms
# Speed: 1.9ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 3 cars, 13.7ms
# Speed: 6.1ms preprocess, 13.7ms inference, 2.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 416x640 1 License_Plate, 7.2ms
# Speed: 2.4ms preprocess, 7.2ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка найдена с координатами: (0, 1, 148, 94), уверенность: 0.792
#
#
# Текст не распознан
#
#
# 0: 448x640 (no detections), 7.3ms
# Speed: 2.5ms preprocess, 7.3ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x576 (no detections), 7.9ms
# Speed: 2.6ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 576)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 3 cars, 19.4ms
# Speed: 2.8ms preprocess, 19.4ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 416x640 1 License_Plate, 6.9ms
# Speed: 1.6ms preprocess, 6.9ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка найдена с координатами: (2, 1, 158, 94), уверенность: 0.712
#
#
# Текст не распознан
#
#
# 0: 480x640 (no detections), 6.8ms
# Speed: 2.5ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x640 (no detections), 8.1ms
# Speed: 3.6ms preprocess, 8.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 3 cars, 11.0ms
# Speed: 4.1ms preprocess, 11.0ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 416x640 1 License_Plate, 7.1ms
# Speed: 2.1ms preprocess, 7.1ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка найдена с координатами: (1, 2, 157, 91), уверенность: 0.750
#
#
# Текст не распознан
#
#
# 0: 448x640 (no detections), 6.7ms
# Speed: 1.9ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 608x640 (no detections), 8.0ms
# Speed: 2.3ms preprocess, 8.0ms inference, 0.7ms postprocess per image at shape (1, 3, 608, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 3 cars, 9.0ms
# Speed: 2.7ms preprocess, 9.0ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 416x640 1 License_Plate, 11.2ms
# Speed: 1.8ms preprocess, 11.2ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка найдена с координатами: (2, 0, 154, 96), уверенность: 0.832
#
#
# Текст не распознан
#
#
# 0: 448x640 (no detections), 9.7ms
# Speed: 1.9ms preprocess, 9.7ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 7.8ms
# Speed: 2.6ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 3 cars, 10.0ms
# Speed: 4.2ms preprocess, 10.0ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 384x640 2 License_Plates, 8.8ms
# Speed: 2.1ms preprocess, 8.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# Номерная табличка найдена с координатами: (1, 7, 156, 91), уверенность: 0.449
#
#
# Текст не распознан
#
#
# 0: 448x640 (no detections), 14.4ms
# Speed: 2.4ms preprocess, 14.4ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 10.0ms
# Speed: 2.8ms preprocess, 10.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 14.9ms
# Speed: 2.7ms preprocess, 14.9ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 384x640 1 License_Plate, 12.9ms
# Speed: 2.4ms preprocess, 12.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# Номерная табличка найдена с координатами: (0, 0, 161, 97), уверенность: 0.657
#
#
# Текст не распознан
#
#
# 0: 448x640 (no detections), 7.4ms
# Speed: 2.5ms preprocess, 7.4ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 9.7ms
# Speed: 5.5ms preprocess, 9.7ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 416x640 1 License_Plate, 19.7ms
# Speed: 3.0ms preprocess, 19.7ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка найдена с координатами: (0, 0, 157, 97), уверенность: 0.770
#
#
# Текст не распознан
#
#
# 0: 416x640 (no detections), 7.3ms
# Speed: 2.2ms preprocess, 7.3ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 12.7ms
# Speed: 2.7ms preprocess, 12.7ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 416x640 2 License_Plates, 6.9ms
# Speed: 1.6ms preprocess, 6.9ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка найдена с координатами: (0, 0, 154, 96), уверенность: 0.764
#
#
# Текст не распознан
#
#
# 0: 416x640 (no detections), 7.4ms
# Speed: 1.7ms preprocess, 7.4ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 9.8ms
# Speed: 8.2ms preprocess, 9.8ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 416x640 1 License_Plate, 8.8ms
# Speed: 1.8ms preprocess, 8.8ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка найдена с координатами: (0, 0, 152, 96), уверенность: 0.473
#
#
# Текст не распознан
#
#
# 0: 352x640 (no detections), 7.3ms
# Speed: 1.5ms preprocess, 7.3ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 9.4ms
# Speed: 3.0ms preprocess, 9.4ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 448x640 (no detections), 10.5ms
# Speed: 2.9ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 320x640 (no detections), 11.8ms
# Speed: 5.4ms preprocess, 11.8ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 3 cars, 15.5ms
# Speed: 2.7ms preprocess, 15.5ms inference, 7.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 448x640 (no detections), 11.0ms
# Speed: 5.6ms preprocess, 11.0ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 320x640 (no detections), 8.8ms
# Speed: 2.2ms preprocess, 8.8ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 9.3ms
# Speed: 2.5ms preprocess, 9.3ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 21.7ms
# Speed: 2.7ms preprocess, 21.7ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 416x640 1 License_Plate, 11.9ms
# Speed: 2.4ms preprocess, 11.9ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка найдена с координатами: (0, 0, 148, 96), уверенность: 0.260
#
#
# Текст не распознан
#
#
# 0: 320x640 (no detections), 7.4ms
# Speed: 1.8ms preprocess, 7.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 9.6ms
# Speed: 2.6ms preprocess, 9.6ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 416x640 (no detections), 8.8ms
# Speed: 1.8ms preprocess, 8.8ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 (no detections), 7.2ms
# Speed: 1.4ms preprocess, 7.2ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 9.8ms
# Speed: 2.7ms preprocess, 9.8ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 448x640 (no detections), 8.5ms
# Speed: 1.7ms preprocess, 8.5ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 (no detections), 7.6ms
# Speed: 2.1ms preprocess, 7.6ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 10.1ms
# Speed: 2.6ms preprocess, 10.1ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 416x640 (no detections), 7.2ms
# Speed: 1.6ms preprocess, 7.2ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 (no detections), 8.2ms
# Speed: 2.0ms preprocess, 8.2ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 10.3ms
# Speed: 2.7ms preprocess, 10.3ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 448x640 (no detections), 7.0ms
# Speed: 2.2ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 (no detections), 7.2ms
# Speed: 1.9ms preprocess, 7.2ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 12.3ms
# Speed: 2.7ms preprocess, 12.3ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 448x640 (no detections), 7.1ms
# Speed: 2.2ms preprocess, 7.1ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 (no detections), 7.1ms
# Speed: 1.4ms preprocess, 7.1ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 11.2ms
# Speed: 2.6ms preprocess, 11.2ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 448x640 (no detections), 6.7ms
# Speed: 1.8ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 (no detections), 7.6ms
# Speed: 1.5ms preprocess, 7.6ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 11.9ms
# Speed: 2.8ms preprocess, 11.9ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 448x640 (no detections), 7.9ms
# Speed: 2.6ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 320x640 (no detections), 15.5ms
# Speed: 2.2ms preprocess, 15.5ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 9.6ms
# Speed: 2.8ms preprocess, 9.6ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 416x640 (no detections), 7.1ms
# Speed: 1.6ms preprocess, 7.1ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка не найдена
#
#
# 0: 320x640 (no detections), 7.3ms
# Speed: 1.5ms preprocess, 7.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 9.7ms
# Speed: 2.9ms preprocess, 9.7ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 416x640 (no detections), 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 (no detections), 7.1ms
# Speed: 1.3ms preprocess, 7.1ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 14.0ms
# Speed: 2.8ms preprocess, 14.0ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 416x640 1 License_Plate, 7.3ms
# Speed: 1.6ms preprocess, 7.3ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка найдена с координатами: (82, 44, 110, 54), уверенность: 0.346
#
#
# Текст не распознан
#
#
# 0: 288x640 (no detections), 7.7ms
# Speed: 2.0ms preprocess, 7.7ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 10.0ms
# Speed: 2.7ms preprocess, 10.0ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 448x640 (no detections), 7.1ms
# Speed: 2.2ms preprocess, 7.1ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 (no detections), 7.9ms
# Speed: 2.0ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 15.5ms
# Speed: 2.8ms preprocess, 15.5ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 448x640 1 License_Plate, 7.3ms
# Speed: 2.0ms preprocess, 7.3ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка найдена с координатами: (76, 47, 105, 56), уверенность: 0.414
#
#
# Текст не распознан
#
#
# 0: 256x640 (no detections), 19.0ms
# Speed: 1.8ms preprocess, 19.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 15.5ms
# Speed: 7.7ms preprocess, 15.5ms inference, 2.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 448x640 1 License_Plate, 14.8ms
# Speed: 3.2ms preprocess, 14.8ms inference, 2.3ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка найдена с координатами: (78, 47, 106, 56), уверенность: 0.359
#
#
# Текст не распознан
#
#
# 0: 256x640 (no detections), 7.5ms
# Speed: 1.9ms preprocess, 7.5ms inference, 0.7ms postprocess per image at shape (1, 3, 256, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 480x640 1 License_Plate, 7.2ms
# Speed: 2.5ms preprocess, 7.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка найдена с координатами: (69, 45, 98, 55), уверенность: 0.293
#
#
# Текст не распознан
#
#
# 0: 256x640 (no detections), 7.4ms
# Speed: 1.8ms preprocess, 7.4ms inference, 0.7ms postprocess per image at shape (1, 3, 256, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 16.9ms
# Speed: 2.8ms preprocess, 16.9ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 480x640 (no detections), 9.2ms
# Speed: 2.6ms preprocess, 9.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 (no detections), 7.7ms
# Speed: 2.1ms preprocess, 7.7ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 9.0ms
# Speed: 2.8ms preprocess, 9.0ms inference, 3.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 480x640 1 License_Plate, 7.2ms
# Speed: 1.8ms preprocess, 7.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка найдена с координатами: (66, 43, 93, 53), уверенность: 0.285
#
#
# Текст не распознан
#
#
# 0: 288x640 (no detections), 7.4ms
# Speed: 1.7ms preprocess, 7.4ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 12.1ms
# Speed: 6.3ms preprocess, 12.1ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 480x640 1 License_Plate, 8.3ms
# Speed: 2.8ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка найдена с координатами: (69, 43, 95, 51), уверенность: 0.283
#
#
# Текст не распознан
#
#
# 0: 288x640 (no detections), 9.6ms
# Speed: 2.1ms preprocess, 9.6ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 10.3ms
# Speed: 3.2ms preprocess, 10.3ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 512x640 1 License_Plate, 8.8ms
# Speed: 2.2ms preprocess, 8.8ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка найдена с координатами: (71, 44, 97, 53), уверенность: 0.402
#
#
# Текст не распознан
#
#
# 0: 288x640 (no detections), 8.2ms
# Speed: 2.0ms preprocess, 8.2ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 16.2ms
# Speed: 8.8ms preprocess, 16.2ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 480x640 1 License_Plate, 8.8ms
# Speed: 2.2ms preprocess, 8.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка найдена с координатами: (72, 42, 98, 51), уверенность: 0.276
#
#
# Текст не распознан
#
#
# 0: 288x640 (no detections), 7.2ms
# Speed: 1.6ms preprocess, 7.2ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 18.3ms
# Speed: 2.8ms preprocess, 18.3ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 448x640 1 License_Plate, 7.8ms
# Speed: 2.0ms preprocess, 7.8ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка найдена с координатами: (70, 41, 96, 50), уверенность: 0.568
#
#
# Текст не распознан
#
#
# 0: 288x640 1 License_Plate, 8.1ms
# Speed: 1.9ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# Номерная табличка найдена с координатами: (0, 47, 338, 146), уверенность: 0.335
#
#
# Текст не распознан
#
#
# 0: 288x640 2 cars, 16.1ms
# Speed: 2.8ms preprocess, 16.1ms inference, 2.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 448x640 1 License_Plate, 13.8ms
# Speed: 2.3ms preprocess, 13.8ms inference, 2.3ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка найдена с координатами: (69, 43, 94, 52), уверенность: 0.290
#
#
# Текст не распознан
#
#
# 0: 288x640 1 License_Plate, 9.4ms
# Speed: 2.7ms preprocess, 9.4ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# Номерная табличка найдена с координатами: (1, 51, 336, 147), уверенность: 0.345
#
#
# Текст не распознан
#
#
# 0: 288x640 2 cars, 11.3ms
# Speed: 4.0ms preprocess, 11.3ms inference, 2.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 448x640 (no detections), 7.1ms
# Speed: 1.8ms preprocess, 7.1ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 1 License_Plate, 7.4ms
# Speed: 1.4ms preprocess, 7.4ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# Номерная табличка найдена с координатами: (3, 49, 334, 146), уверенность: 0.317
#
#
# Текст не распознан
#
#
# 0: 288x640 2 cars, 13.1ms
# Speed: 2.4ms preprocess, 13.1ms inference, 6.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 448x640 (no detections), 7.0ms
# Speed: 2.2ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 1 License_Plate, 7.3ms
# Speed: 1.3ms preprocess, 7.3ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# Номерная табличка найдена с координатами: (2, 51, 335, 146), уверенность: 0.425
#
#
# Текст не распознан
#
#
# 0: 288x640 2 cars, 15.3ms
# Speed: 2.8ms preprocess, 15.3ms inference, 5.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 448x640 1 License_Plate, 12.1ms
# Speed: 2.4ms preprocess, 12.1ms inference, 1.9ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка найдена с координатами: (68, 43, 92, 51), уверенность: 0.442
#
#
# Текст не распознан
#
#
# 0: 288x640 1 License_Plate, 8.3ms
# Speed: 2.0ms preprocess, 8.3ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# Номерная табличка найдена с координатами: (0, 48, 320, 140), уверенность: 0.439
#
#
# Текст не распознан
#
#
# 0: 288x640 2 cars, 14.6ms
# Speed: 2.8ms preprocess, 14.6ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 448x640 1 License_Plate, 6.7ms
# Speed: 2.0ms preprocess, 6.7ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка найдена с координатами: (71, 43, 95, 51), уверенность: 0.481
#
#
# Текст не распознан
#
#
# 0: 320x640 1 License_Plate, 8.3ms
# Speed: 2.0ms preprocess, 8.3ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# Номерная табличка найдена с координатами: (0, 54, 314, 142), уверенность: 0.256
#
#
# Текст не распознан
#
#
# 0: 288x640 2 cars, 12.9ms
# Speed: 3.7ms preprocess, 12.9ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 448x640 1 License_Plate, 12.6ms
# Speed: 2.4ms preprocess, 12.6ms inference, 2.6ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка найдена с координатами: (65, 39, 89, 48), уверенность: 0.415
#
#
# Текст не распознан
#
#
# 0: 288x640 (no detections), 7.3ms
# Speed: 1.3ms preprocess, 7.3ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 10.0ms
# Speed: 2.7ms preprocess, 10.0ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 480x640 1 License_Plate, 9.8ms
# Speed: 2.2ms preprocess, 9.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка найдена с координатами: (66, 38, 90, 47), уверенность: 0.294
#
#
# Текст не распознан
#
#
# 0: 288x640 (no detections), 7.1ms
# Speed: 1.3ms preprocess, 7.1ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 3 cars, 10.3ms
# Speed: 2.5ms preprocess, 10.3ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 480x640 1 License_Plate, 8.3ms
# Speed: 2.2ms preprocess, 8.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка найдена с координатами: (68, 39, 92, 48), уверенность: 0.266
#
#
# Текст не распознан
#
#
# 0: 288x640 (no detections), 7.8ms
# Speed: 2.1ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x640 (no detections), 7.4ms
# Speed: 3.2ms preprocess, 7.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 3 cars, 11.7ms
# Speed: 4.1ms preprocess, 11.7ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 480x640 1 License_Plate, 6.9ms
# Speed: 1.9ms preprocess, 6.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка найдена с координатами: (64, 39, 88, 48), уверенность: 0.529
#
#
# Текст не распознан
#
#
# 0: 288x640 (no detections), 9.9ms
# Speed: 1.5ms preprocess, 9.9ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x576 (no detections), 9.2ms
# Speed: 2.4ms preprocess, 9.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 576)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 3 cars, 9.9ms
# Speed: 2.7ms preprocess, 9.9ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 480x640 1 License_Plate, 13.2ms
# Speed: 2.6ms preprocess, 13.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка найдена с координатами: (63, 40, 87, 49), уверенность: 0.548
#
#
# Текст не распознан
#
#
# 0: 288x640 (no detections), 7.6ms
# Speed: 1.3ms preprocess, 7.6ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x640 (no detections), 7.4ms
# Speed: 2.3ms preprocess, 7.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 3 cars, 16.4ms
# Speed: 3.2ms preprocess, 16.4ms inference, 4.9ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 480x640 1 License_Plate, 7.2ms
# Speed: 2.4ms preprocess, 7.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка найдена с координатами: (63, 40, 87, 48), уверенность: 0.437
#
#
# Текст не распознан
#
#
# 0: 320x640 (no detections), 7.3ms
# Speed: 1.4ms preprocess, 7.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x608 (no detections), 35.1ms
# Speed: 2.2ms preprocess, 35.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 608)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 3 cars, 13.0ms
# Speed: 2.8ms preprocess, 13.0ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 480x640 1 License_Plate, 6.7ms
# Speed: 1.8ms preprocess, 6.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка найдена с координатами: (65, 40, 89, 47), уверенность: 0.334
#
#
# Текст не распознан
#
#
# 0: 320x640 (no detections), 7.2ms
# Speed: 1.8ms preprocess, 7.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x608 (no detections), 9.3ms
# Speed: 2.4ms preprocess, 9.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 3 cars, 16.5ms
# Speed: 2.8ms preprocess, 16.5ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 480x640 (no detections), 7.5ms
# Speed: 1.8ms preprocess, 7.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 320x640 (no detections), 8.5ms
# Speed: 2.4ms preprocess, 8.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 7.8ms
# Speed: 2.0ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 3 cars, 10.6ms
# Speed: 2.8ms preprocess, 10.6ms inference, 4.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 512x640 (no detections), 8.5ms
# ...
#
# 0: 448x640 (no detections), 8.0ms
# Speed: 2.9ms preprocess, 8.0ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.7ms preprocess, 7.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 10.3ms
# Speed: 3.5ms preprocess, 10.3ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 416x640 (no detections), 7.0ms
# Speed: 1.8ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 6.8ms
# Speed: 1.9ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 17.1ms
# Speed: 2.7ms preprocess, 17.1ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 416x640 (no detections), 7.9ms
# Speed: 2.7ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.8ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 12.4ms
# Speed: 2.6ms preprocess, 12.4ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 416x640 (no detections), 7.1ms
# Speed: 1.8ms preprocess, 7.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.7ms preprocess, 7.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 10.0ms
# Speed: 2.7ms preprocess, 10.0ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 384x640 (no detections), 9.1ms
# Speed: 1.9ms preprocess, 9.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 7.3ms
# Speed: 2.5ms preprocess, 7.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 13.7ms
# Speed: 3.6ms preprocess, 13.7ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 352x640 (no detections), 7.5ms
# Speed: 1.6ms preprocess, 7.5ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 8.3ms
# Speed: 1.9ms preprocess, 8.3ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 10.4ms
# Speed: 2.6ms preprocess, 10.4ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 320x640 (no detections), 7.2ms
# Speed: 1.5ms preprocess, 7.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 6.9ms
# Speed: 1.8ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 1 car, 14.9ms
# Speed: 3.2ms preprocess, 14.9ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 512x640 (no detections), 6.9ms
# Speed: 1.9ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 1 car, 10.5ms
# Speed: 2.8ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 512x640 (no detections), 7.1ms
# Speed: 2.5ms preprocess, 7.1ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 1 car, 11.6ms
# Speed: 2.5ms preprocess, 11.6ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 512x640 (no detections), 6.9ms
# Speed: 2.8ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 2 cars, 9.8ms
# Speed: 5.8ms preprocess, 9.8ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 544x640 (no detections), 8.2ms
# Speed: 2.1ms preprocess, 8.2ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 (no detections), 7.6ms
# Speed: 1.9ms preprocess, 7.6ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 1 car, 11.0ms
# Speed: 2.7ms preprocess, 11.0ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 576x640 (no detections), 8.5ms
# Speed: 2.2ms preprocess, 8.5ms inference, 0.8ms postprocess per image at shape (1, 3, 576, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 1 car, 9.8ms
# Speed: 2.7ms preprocess, 9.8ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 576x640 (no detections), 7.8ms
# Speed: 2.2ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 1 car, 12.5ms
# Speed: 3.3ms preprocess, 12.5ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 608x640 (no detections), 7.9ms
# Speed: 2.0ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 608, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 1 car, 10.3ms
# Speed: 2.9ms preprocess, 10.3ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 576x640 (no detections), 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 1 car, 11.6ms
# Speed: 2.4ms preprocess, 11.6ms inference, 3.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 576x640 (no detections), 7.8ms
# Speed: 2.1ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 1 car, 10.1ms
# Speed: 2.6ms preprocess, 10.1ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 576x640 (no detections), 7.9ms
# Speed: 2.0ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 1 car, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 608x640 (no detections), 7.9ms
# Speed: 2.0ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 608, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 1 car, 9.8ms
# Speed: 2.5ms preprocess, 9.8ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 608x640 (no detections), 9.0ms
# Speed: 2.4ms preprocess, 9.0ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 1 car, 9.6ms
# Speed: 2.8ms preprocess, 9.6ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 544x640 (no detections), 7.8ms
# Speed: 1.8ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 288x640 1 car, 11.3ms
# Speed: 3.0ms preprocess, 11.3ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 car, 9.4ms
# Speed: 2.7ms preprocess, 9.4ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 car, 11.6ms
# Speed: 2.7ms preprocess, 11.6ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 car, 9.7ms
# Speed: 3.1ms preprocess, 9.7ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 car, 10.2ms
# Speed: 2.6ms preprocess, 10.2ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 car, 9.8ms
# Speed: 2.6ms preprocess, 9.8ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 car, 10.8ms
# Speed: 2.6ms preprocess, 10.8ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 car, 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 car, 9.7ms
# Speed: 2.7ms preprocess, 9.7ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 cars, 7.4ms
# Speed: 2.6ms preprocess, 7.4ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 cars, 7.7ms
# Speed: 2.8ms preprocess, 7.7ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 cars, 12.3ms
# Speed: 2.7ms preprocess, 12.3ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 3 cars, 9.6ms
# Speed: 2.8ms preprocess, 9.6ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 3 cars, 11.7ms
# Speed: 2.8ms preprocess, 11.7ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 3 cars, 10.6ms
# Speed: 2.5ms preprocess, 10.6ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 3 cars, 16.8ms
# Speed: 2.6ms preprocess, 16.8ms inference, 2.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 3 cars, 9.7ms
# Speed: 2.6ms preprocess, 9.7ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 3 cars, 10.4ms
# Speed: 2.5ms preprocess, 10.4ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 3 cars, 10.3ms
# Speed: 2.7ms preprocess, 10.3ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 3 cars, 10.1ms
# Speed: 2.6ms preprocess, 10.1ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 3 cars, 11.1ms
# Speed: 2.7ms preprocess, 11.1ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 3 cars, 7.9ms
# Speed: 2.9ms preprocess, 7.9ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 3 cars, 8.9ms
# Speed: 2.7ms preprocess, 8.9ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 cars, 12.5ms
# Speed: 2.6ms preprocess, 12.5ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 cars, 17.3ms
# Speed: 4.6ms preprocess, 17.3ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 cars, 9.5ms
# Speed: 2.8ms preprocess, 9.5ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 cars, 12.8ms
# Speed: 2.7ms preprocess, 12.8ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 car, 9.9ms
# Speed: 3.8ms preprocess, 9.9ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 car, 8.9ms
# Speed: 2.7ms preprocess, 8.9ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 car, 16.2ms
# Speed: 5.9ms preprocess, 16.2ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 car, 10.9ms
# Speed: 2.7ms preprocess, 10.9ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 car, 7.1ms
# Speed: 2.2ms preprocess, 7.1ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 car, 9.7ms
# Speed: 2.5ms preprocess, 9.7ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 cars, 10.6ms
# Speed: 2.6ms preprocess, 10.6ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 car, 10.1ms
# Speed: 2.6ms preprocess, 10.1ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 car, 12.3ms
# Speed: 3.9ms preprocess, 12.3ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 car, 11.1ms
# Speed: 2.6ms preprocess, 11.1ms inference, 2.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 car, 10.7ms
# Speed: 2.6ms preprocess, 10.7ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 cars, 10.3ms
# Speed: 2.7ms preprocess, 10.3ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 3 cars, 10.4ms
# Speed: 2.5ms preprocess, 10.4ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 3 cars, 10.1ms
# Speed: 2.8ms preprocess, 10.1ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 cars, 10.2ms
# Speed: 2.7ms preprocess, 10.2ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 cars, 9.4ms
# Speed: 2.7ms preprocess, 9.4ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 car, 10.2ms
# Speed: 2.5ms preprocess, 10.2ms inference, 2.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 cars, 17.7ms
# Speed: 2.6ms preprocess, 17.7ms inference, 6.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 cars, 14.7ms
# Speed: 3.7ms preprocess, 14.7ms inference, 2.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 cars, 12.9ms
# Speed: 4.2ms preprocess, 12.9ms inference, 2.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 cars, 10.9ms
# Speed: 2.7ms preprocess, 10.9ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 cars, 11.3ms
# Speed: 2.6ms preprocess, 11.3ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 cars, 19.5ms
# Speed: 2.7ms preprocess, 19.5ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 cars, 22.0ms
# Speed: 2.6ms preprocess, 22.0ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 cars, 19.4ms
# Speed: 2.7ms preprocess, 19.4ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 cars, 10.1ms
# Speed: 2.6ms preprocess, 10.1ms inference, 5.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 cars, 16.6ms
# Speed: 2.9ms preprocess, 16.6ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 cars, 21.4ms
# Speed: 2.7ms preprocess, 21.4ms inference, 4.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 cars, 20.1ms
# Speed: 2.7ms preprocess, 20.1ms inference, 2.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 cars, 11.6ms
# Speed: 4.3ms preprocess, 11.6ms inference, 2.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 cars, 9.9ms
# Speed: 4.6ms preprocess, 9.9ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 cars, 11.7ms
# Speed: 7.1ms preprocess, 11.7ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 cars, 15.6ms
# Speed: 3.8ms preprocess, 15.6ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 3 cars, 16.6ms
# Speed: 2.8ms preprocess, 16.6ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 3 cars, 18.8ms
# Speed: 6.2ms preprocess, 18.8ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 3 cars, 21.7ms
# Speed: 4.0ms preprocess, 21.7ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 cars, 16.7ms
# Speed: 3.1ms preprocess, 16.7ms inference, 7.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 3 cars, 13.7ms
# Speed: 9.6ms preprocess, 13.7ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 3 cars, 19.9ms
# Speed: 2.5ms preprocess, 19.9ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 3 cars, 14.7ms
# Speed: 2.7ms preprocess, 14.7ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 3 cars, 13.0ms
# Speed: 2.6ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 3 cars, 28.5ms
# Speed: 2.9ms preprocess, 28.5ms inference, 4.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 3 cars, 11.7ms
# Speed: 3.0ms preprocess, 11.7ms inference, 2.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 3 cars, 13.8ms
# Speed: 2.7ms preprocess, 13.8ms inference, 2.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 3 cars, 11.2ms
# Speed: 2.8ms preprocess, 11.2ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
# Логи распознанных номеров сохранены по пути: /content/drive/MyDrive/Tracking/detected_plates_uglich.csv
# Видео с тепловой картой и номерами сохранено по пути: /content/drive/MyDrive/Tracking/tracked_video_uglich.mp4

# %%
# Отображение видео с трекингом
display_video(tracked_video_path)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Путь к исходному видео
original_video_path = f'{base_path}/camera_moscow.mp4'

# Путь к обработанному видео
tracked_video_path = f'{base_path}/tracked_video_moscow.mp4'

# Путь к файлу с результатами обнаруженных автомобильных номеров
csv_output_path = f'{base_path}/detected_plates_moscow.csv'

# %%
run_tracking_pipeline(
    original_video_path=original_video_path,
    tracked_video_path=tracked_video_path,
    base_path=base_path,
    model_cars=model_cars,
    pipeline_image=pipline_image,  # OCR-модель
    csv_output_path=csv_output_path
)
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#
# 0: 448x640 (no detections), 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 6.8ms
# Speed: 1.7ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 6.7ms
# Speed: 1.6ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 7.8ms
# Speed: 1.9ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x512 (no detections), 8.9ms
# Speed: 2.5ms preprocess, 8.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 512)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 11.6ms
# Speed: 2.6ms preprocess, 11.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 576x640 (no detections), 10.2ms
# Speed: 2.3ms preprocess, 10.2ms inference, 0.9ms postprocess per image at shape (1, 3, 576, 640)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 6.8ms
# Speed: 1.6ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 6.9ms
# Speed: 1.8ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 7.8ms
# Speed: 1.9ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 6.9ms
# Speed: 1.9ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x640 (no detections), 7.3ms
# Speed: 2.1ms preprocess, 7.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 14.2ms
# Speed: 2.5ms preprocess, 14.2ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 7.8ms
# Speed: 2.6ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 6.7ms
# Speed: 1.6ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 7.2ms
# Speed: 2.0ms preprocess, 7.2ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 384x640 20 cars, 9.7ms
# Speed: 3.9ms preprocess, 9.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 (no detections), 7.2ms
# Speed: 1.3ms preprocess, 7.2ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 6.8ms
# Speed: 1.7ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 9.0ms
# Speed: 1.8ms preprocess, 9.0ms inference, 0.8ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 6.7ms
# Speed: 1.6ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 8.4ms
# Speed: 2.5ms preprocess, 8.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 7.2ms
# Speed: 1.7ms preprocess, 7.2ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x512 (no detections), 6.9ms
# Speed: 1.7ms preprocess, 6.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 512)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 9.6ms
# Speed: 2.7ms preprocess, 9.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 11.9ms
# Speed: 2.7ms preprocess, 11.9ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 8.8ms
# Speed: 2.5ms preprocess, 8.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 8.9ms
# Speed: 2.3ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 608x640 (no detections), 8.2ms
# Speed: 3.4ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 608, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 8.3ms
# Speed: 2.5ms preprocess, 8.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x640 (no detections), 8.4ms
# Speed: 2.9ms preprocess, 8.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 10.1ms
# Speed: 2.5ms preprocess, 10.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 8.9ms
# Speed: 4.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 10.4ms
# Speed: 2.4ms preprocess, 10.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 11.4ms
# Speed: 2.4ms preprocess, 11.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 17.6ms
# Speed: 2.3ms preprocess, 17.6ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 2 License_Plates, 8.1ms
# Speed: 2.5ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка найдена с координатами: (13, 0, 61, 44), уверенность: 0.643
#
#
# Текст не распознан
#
#
# 0: 384x640 19 cars, 9.6ms
# Speed: 4.2ms preprocess, 9.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 (no detections), 7.1ms
# Speed: 1.4ms preprocess, 7.1ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 7.2ms
# Speed: 1.8ms preprocess, 7.2ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 6.9ms
# Speed: 1.6ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 6.8ms
# Speed: 1.8ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 8.5ms
# Speed: 1.9ms preprocess, 8.5ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 7.1ms
# Speed: 1.7ms preprocess, 7.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x512 (no detections), 6.8ms
# Speed: 1.8ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 512)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 7.7ms
# Speed: 1.9ms preprocess, 7.7ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 6.7ms
# Speed: 2.6ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 6.9ms
# Speed: 1.7ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 8.4ms
# Speed: 1.8ms preprocess, 8.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 576x640 (no detections), 7.8ms
# Speed: 1.9ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 6.8ms
# Speed: 1.7ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 7.1ms
# Speed: 1.7ms preprocess, 7.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x640 (no detections), 7.3ms
# Speed: 2.1ms preprocess, 7.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 6.7ms
# Speed: 1.7ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 8.4ms
# Speed: 1.9ms preprocess, 8.4ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 6.7ms
# Speed: 1.7ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 1 License_Plate, 6.9ms
# Speed: 1.7ms preprocess, 6.9ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка найдена с координатами: (12, 0, 67, 41), уверенность: 0.327
#
#
# Распознанный текст: 15, уверенность: 0.468
#
#
# 0: 384x640 19 cars, 11.2ms
# Speed: 4.3ms preprocess, 11.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 (no detections), 8.2ms
# Speed: 2.0ms preprocess, 8.2ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 9.2ms
# Speed: 2.0ms preprocess, 9.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 7.1ms
# Speed: 2.4ms preprocess, 7.1ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 8.3ms
# Speed: 2.6ms preprocess, 8.3ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 7.7ms
# Speed: 1.8ms preprocess, 7.7ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 6.9ms
# Speed: 1.6ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x512 (no detections), 7.1ms
# Speed: 2.4ms preprocess, 7.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 512)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 7.7ms
# Speed: 1.8ms preprocess, 7.7ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 10.4ms
# Speed: 2.4ms preprocess, 10.4ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 6.8ms
# Speed: 1.8ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 7.1ms
# Speed: 2.1ms preprocess, 7.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 576x640 (no detections), 7.8ms
# Speed: 2.0ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 9.5ms
# Speed: 2.2ms preprocess, 9.5ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 6.8ms
# Speed: 1.8ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x640 (no detections), 11.8ms
# Speed: 5.3ms preprocess, 11.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 9.9ms
# Speed: 2.3ms preprocess, 9.9ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 8.8ms
# Speed: 3.2ms preprocess, 8.8ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 9.4ms
# Speed: 2.3ms preprocess, 9.4ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 10.8ms
# Speed: 2.4ms preprocess, 10.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 384x640 17 cars, 21.0ms
# Speed: 3.4ms preprocess, 21.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 (no detections), 9.8ms
# Speed: 1.8ms preprocess, 9.8ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 13.6ms
# Speed: 2.6ms preprocess, 13.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 10.0ms
# Speed: 2.3ms preprocess, 10.0ms inference, 3.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 8.8ms
# Speed: 5.1ms preprocess, 8.8ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 8.6ms
# Speed: 2.7ms preprocess, 8.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 8.9ms
# Speed: 2.4ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x512 (no detections), 8.2ms
# Speed: 2.6ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 512)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 8.6ms
# Speed: 2.2ms preprocess, 8.6ms inference, 0.8ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 8.0ms
# Speed: 2.5ms preprocess, 8.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 11.6ms
# Speed: 2.8ms preprocess, 11.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 576x640 (no detections), 10.5ms
# Speed: 3.0ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 11.9ms
# Speed: 2.6ms preprocess, 11.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 7.3ms
# Speed: 2.6ms preprocess, 7.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 576x640 (no detections), 7.8ms
# Speed: 2.0ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 7.1ms
# Speed: 1.7ms preprocess, 7.1ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 7.7ms
# Speed: 1.7ms preprocess, 7.7ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 384x640 16 cars, 10.0ms
# Speed: 6.9ms preprocess, 10.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 (no detections), 7.1ms
# Speed: 1.3ms preprocess, 7.1ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 8.4ms
# Speed: 1.9ms preprocess, 8.4ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 6.9ms
# Speed: 1.7ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 6.8ms
# Speed: 1.7ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 9.3ms
# Speed: 2.6ms preprocess, 9.3ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 6.7ms
# Speed: 1.6ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x576 (no detections), 7.8ms
# Speed: 1.9ms preprocess, 7.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 576)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 8.6ms
# Speed: 1.8ms preprocess, 8.6ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 6.7ms
# Speed: 1.7ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 8.2ms
# Speed: 2.0ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 7.7ms
# Speed: 1.9ms preprocess, 7.7ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 6.9ms
# Speed: 1.6ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 6.8ms
# Speed: 1.6ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 6.8ms
# Speed: 1.8ms preprocess, 6.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 576x640 (no detections), 8.6ms
# Speed: 2.3ms preprocess, 8.6ms inference, 0.8ms postprocess per image at shape (1, 3, 576, 640)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 6.6ms
# Speed: 1.6ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 384x640 16 cars, 11.1ms
# Speed: 3.4ms preprocess, 11.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 (no detections), 8.7ms
# Speed: 1.9ms preprocess, 8.7ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 9.1ms
# Speed: 1.9ms preprocess, 9.1ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 7.0ms
# Speed: 1.9ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 8.8ms
# Speed: 2.0ms preprocess, 8.8ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 6.7ms
# Speed: 1.6ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x544 (no detections), 7.8ms
# Speed: 2.0ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 544)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 6.9ms
# Speed: 1.8ms preprocess, 6.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 6.8ms
# Speed: 1.7ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 7.8ms
# Speed: 2.4ms preprocess, 7.8ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 576x640 (no detections), 8.9ms
# Speed: 2.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 576, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 6.8ms
# Speed: 1.7ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 6.7ms
# Speed: 1.7ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 6.9ms
# Speed: 1.8ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 7.8ms
# Speed: 1.9ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 6.9ms
# Speed: 1.6ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 384x640 18 cars, 11.1ms
# Speed: 3.4ms preprocess, 11.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 (no detections), 9.7ms
# Speed: 1.5ms preprocess, 9.7ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 6.9ms
# Speed: 1.8ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 7.8ms
# Speed: 1.8ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 6.9ms
# Speed: 1.7ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 6.7ms
# Speed: 1.8ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.6ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x512 (no detections), 6.9ms
# Speed: 1.8ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 512)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 7.3ms
# Speed: 1.6ms preprocess, 7.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 8.7ms
# Speed: 2.0ms preprocess, 8.7ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 8.1ms
# Speed: 2.6ms preprocess, 8.1ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 7.8ms
# Speed: 1.9ms preprocess, 7.8ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 6.7ms
# Speed: 1.7ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 7.5ms
# Speed: 1.7ms preprocess, 7.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 7.2ms
# Speed: 1.7ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 6.7ms
# Speed: 1.6ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 416x640 (no detections), 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка не найдена
#
#
# 0: 576x640 (no detections), 7.8ms
# Speed: 1.9ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# Номерная табличка не найдена
#
#
# 0: 384x640 16 cars, 11.8ms
# Speed: 3.4ms preprocess, 11.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 (no detections), 8.4ms
# Speed: 2.0ms preprocess, 8.4ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 6.9ms
# Speed: 1.8ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 7.7ms
# Speed: 1.9ms preprocess, 7.7ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 7.8ms
# Speed: 1.9ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 7.7ms
# Speed: 2.7ms preprocess, 7.7ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 6.8ms
# Speed: 1.7ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 6.9ms
# Speed: 1.8ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 10.2ms
# Speed: 2.7ms preprocess, 10.2ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 11.8ms
# Speed: 2.5ms preprocess, 11.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 576x640 (no detections), 8.4ms
# Speed: 2.8ms preprocess, 8.4ms inference, 0.8ms postprocess per image at shape (1, 3, 576, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 8.5ms
# Speed: 2.5ms preprocess, 8.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 8.5ms
# Speed: 2.6ms preprocess, 8.5ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 8.1ms
# Speed: 2.6ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 384x640 (no detections), 9.1ms
# Speed: 2.2ms preprocess, 9.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# Номерная табличка не найдена
#
#
# 0: 416x640 (no detections), 13.8ms
# Speed: 2.1ms preprocess, 13.8ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка не найдена
#
#
# 0: 576x640 (no detections), 9.1ms
# Speed: 2.8ms preprocess, 9.1ms inference, 0.8ms postprocess per image at shape (1, 3, 576, 640)
#
# Номерная табличка не найдена
#
#
# 0: 384x640 16 cars, 17.3ms
# Speed: 3.8ms preprocess, 17.3ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 (no detections), 9.6ms
# Speed: 1.9ms preprocess, 9.6ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 8.9ms
# Speed: 2.9ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 576x640 (no detections), 8.5ms
# Speed: 2.8ms preprocess, 8.5ms inference, 0.8ms postprocess per image at shape (1, 3, 576, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 8.1ms
# Speed: 2.6ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 8.2ms
# Speed: 2.7ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 12.1ms
# Speed: 4.8ms preprocess, 12.1ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 16.3ms
# Speed: 3.3ms preprocess, 16.3ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 12.0ms
# Speed: 2.5ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 13.6ms
# Speed: 4.2ms preprocess, 13.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 576x640 (no detections), 7.8ms
# Speed: 1.9ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 7.4ms
# Speed: 2.8ms preprocess, 7.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 8.4ms
# Speed: 1.9ms preprocess, 8.4ms inference, 0.8ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 6.7ms
# Speed: 1.8ms preprocess, 6.7ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 384x640 (no detections), 7.1ms
# Speed: 1.4ms preprocess, 7.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 8.2ms
# Speed: 2.4ms preprocess, 8.2ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 576x640 (no detections), 7.8ms
# Speed: 1.9ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# Номерная табличка не найдена
#
#
# 0: 384x640 15 cars, 8.1ms
# Speed: 3.3ms preprocess, 8.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 7.3ms
# Speed: 1.5ms preprocess, 7.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 7.7ms
# Speed: 1.8ms preprocess, 7.7ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 576x640 (no detections), 7.8ms
# Speed: 2.0ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 6.7ms
# Speed: 1.7ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 7.7ms
# Speed: 2.2ms preprocess, 7.7ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 608x640 (no detections), 7.9ms
# Speed: 2.0ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 608, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 6.8ms
# Speed: 1.7ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 7.7ms
# Speed: 1.9ms preprocess, 7.7ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 576x640 (no detections), 8.1ms
# Speed: 2.2ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 576, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 6.6ms
# Speed: 1.6ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 7.8ms
# Speed: 2.0ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 352x640 (no detections), 7.1ms
# Speed: 1.4ms preprocess, 7.1ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 6.9ms
# Speed: 1.6ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 608x640 (no detections), 8.5ms
# Speed: 2.3ms preprocess, 8.5ms inference, 0.7ms postprocess per image at shape (1, 3, 608, 640)
#
# Номерная табличка не найдена
#
#
# 0: 384x640 19 cars, 7.5ms
# Speed: 3.6ms preprocess, 7.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 (no detections), 7.5ms
# Speed: 1.3ms preprocess, 7.5ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 7.1ms
# Speed: 1.9ms preprocess, 7.1ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 6.9ms
# Speed: 1.8ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 7.2ms
# Speed: 1.8ms preprocess, 7.2ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 9.1ms
# Speed: 2.8ms preprocess, 9.1ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x640 (no detections), 7.3ms
# Speed: 2.2ms preprocess, 7.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 9.4ms
# Speed: 2.1ms preprocess, 9.4ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 9.3ms
# Speed: 1.8ms preprocess, 9.3ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 608x640 (no detections), 7.9ms
# Speed: 2.0ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 608, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 6.7ms
# Speed: 1.7ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 7.8ms
# Speed: 1.9ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 352x640 (no detections), 7.0ms
# Speed: 1.3ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 6.8ms
# Speed: 2.5ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x608 (no detections), 8.0ms
# Speed: 2.3ms preprocess, 8.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 6.9ms
# Speed: 1.6ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 576x640 (no detections), 8.6ms
# Speed: 2.1ms preprocess, 8.6ms inference, 0.8ms postprocess per image at shape (1, 3, 576, 640)
#
# Номерная табличка не найдена
#
#
# 0: 576x640 (no detections), 7.8ms
# Speed: 2.0ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 6.7ms
# Speed: 1.6ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 384x640 19 cars, 12.0ms
# Speed: 3.5ms preprocess, 12.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 (no detections), 7.7ms
# Speed: 1.3ms preprocess, 7.7ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 6.8ms
# Speed: 1.8ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 7.4ms
# Speed: 1.9ms preprocess, 7.4ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 7.2ms
# Speed: 1.8ms preprocess, 7.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 576x640 (no detections), 8.7ms
# Speed: 2.3ms preprocess, 8.7ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x640 (no detections), 7.3ms
# Speed: 2.2ms preprocess, 7.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 7.9ms
# Speed: 2.5ms preprocess, 7.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 7.9ms
# Speed: 1.9ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 608x640 (no detections), 8.0ms
# Speed: 2.1ms preprocess, 8.0ms inference, 0.7ms postprocess per image at shape (1, 3, 608, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 6.9ms
# Speed: 1.8ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 9.6ms
# Speed: 2.0ms preprocess, 9.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 7.8ms
# Speed: 1.9ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 384x640 (no detections), 7.5ms
# Speed: 2.1ms preprocess, 7.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# Номерная табличка не найдена
#
#
# 0: 384x640 (no detections), 10.9ms
# Speed: 1.6ms preprocess, 10.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# Номерная табличка не найдена
#
#
# 0: 608x640 (no detections), 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 0.7ms postprocess per image at shape (1, 3, 608, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x640 (no detections), 7.4ms
# Speed: 3.3ms preprocess, 7.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# Номерная табличка не найдена
#
#
# 0: 576x640 (no detections), 7.9ms
# Speed: 2.2ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# Номерная табличка не найдена
#
#
# 0: 608x640 (no detections), 7.9ms
# Speed: 2.0ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 608, 640)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 7.1ms
# Speed: 1.9ms preprocess, 7.1ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 384x640 18 cars, 12.8ms
# Speed: 3.3ms preprocess, 12.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 (no detections), 7.4ms
# Speed: 1.3ms preprocess, 7.4ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 7.1ms
# Speed: 1.8ms preprocess, 7.1ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 7.3ms
# Speed: 1.7ms preprocess, 7.3ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 8.8ms
# Speed: 2.7ms preprocess, 8.8ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 9.2ms
# Speed: 2.5ms preprocess, 9.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 9.3ms
# Speed: 2.7ms preprocess, 9.3ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 576x640 (no detections), 10.6ms
# Speed: 3.0ms preprocess, 10.6ms inference, 0.9ms postprocess per image at shape (1, 3, 576, 640)
#
# Номерная табличка не найдена
#
#
# 0: 576x640 (no detections), 8.8ms
# Speed: 2.9ms preprocess, 8.8ms inference, 0.8ms postprocess per image at shape (1, 3, 576, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 8.3ms
# Speed: 2.3ms preprocess, 8.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 11.6ms
# Speed: 2.6ms preprocess, 11.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 352x640 (no detections), 8.9ms
# Speed: 2.1ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка не найдена
#
#
# 0: 416x640 (no detections), 9.4ms
# Speed: 2.2ms preprocess, 9.4ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 8.5ms
# Speed: 2.7ms preprocess, 8.5ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x640 (no detections), 8.4ms
# Speed: 3.1ms preprocess, 8.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# Номерная табличка не найдена
#
#
# 0: 576x640 (no detections), 11.0ms
# Speed: 3.1ms preprocess, 11.0ms inference, 0.8ms postprocess per image at shape (1, 3, 576, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 8.2ms
# Speed: 2.5ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 416x640 (no detections), 13.8ms
# Speed: 2.0ms preprocess, 13.8ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка не найдена
#
#
# 0: 320x640 (no detections), 9.8ms
# Speed: 1.8ms preprocess, 9.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# Номерная табличка не найдена
#
#
# 0: 384x640 19 cars, 8.6ms
# Speed: 3.4ms preprocess, 8.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 (no detections), 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 6.7ms
# Speed: 1.8ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 416x640 (no detections), 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 6.9ms
# Speed: 1.8ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 6.9ms
# Speed: 1.7ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 7.3ms
# Speed: 1.9ms preprocess, 7.3ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 576x640 (no detections), 7.9ms
# Speed: 2.0ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# Номерная табличка не найдена
#
#
# 0: 608x640 (no detections), 7.9ms
# Speed: 2.7ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 608, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 6.8ms
# Speed: 1.9ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 7.0ms
# Speed: 2.5ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 320x640 (no detections), 8.6ms
# Speed: 1.3ms preprocess, 8.6ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# Номерная табличка не найдена
#
#
# 0: 416x640 (no detections), 6.9ms
# Speed: 1.6ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 7.4ms
# Speed: 1.8ms preprocess, 7.4ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x608 (no detections), 7.9ms
# Speed: 2.1ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 9.1ms
# Speed: 1.9ms preprocess, 9.1ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 7.7ms
# Speed: 1.9ms preprocess, 7.7ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 384x640 (no detections), 7.1ms
# Speed: 1.4ms preprocess, 7.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# Номерная табличка не найдена
#
#
# 0: 320x640 (no detections), 7.5ms
# Speed: 1.2ms preprocess, 7.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# Номерная табличка не найдена
#
#
# 0: 576x640 (no detections), 11.4ms
# Speed: 2.1ms preprocess, 11.4ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# Номерная табличка не найдена
#
#
# 0: 384x640 19 cars, 9.9ms
# Speed: 5.0ms preprocess, 9.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 (no detections), 7.2ms
# Speed: 1.3ms preprocess, 7.2ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 6.8ms
# Speed: 1.8ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 416x640 (no detections), 7.0ms
# Speed: 1.6ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 7.2ms
# Speed: 1.7ms preprocess, 7.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 8.5ms
# Speed: 2.3ms preprocess, 8.5ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 6.8ms
# Speed: 1.6ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 608x640 (no detections), 8.3ms
# Speed: 3.3ms preprocess, 8.3ms inference, 0.7ms postprocess per image at shape (1, 3, 608, 640)
#
# Номерная табличка не найдена
#
#
# 0: 608x640 (no detections), 7.9ms
# Speed: 2.0ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 608, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 7.5ms
# Speed: 1.8ms preprocess, 7.5ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 7.2ms
# Speed: 1.8ms preprocess, 7.2ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 320x640 (no detections), 9.8ms
# Speed: 1.5ms preprocess, 9.8ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 7.9ms
# Speed: 2.6ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 6.8ms
# Speed: 1.7ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x608 (no detections), 8.0ms
# Speed: 2.1ms preprocess, 8.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
#
# Номерная табличка не найдена
#
#
# 0: 576x640 (no detections), 7.8ms
# Speed: 1.9ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 7.7ms
# Speed: 1.8ms preprocess, 7.7ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 6.7ms
# Speed: 1.6ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 352x640 (no detections), 7.5ms
# Speed: 1.4ms preprocess, 7.5ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 7.7ms
# Speed: 1.9ms preprocess, 7.7ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# ...
#
# 0: 352x640 (no detections), 11.4ms
# Speed: 1.9ms preprocess, 11.4ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 8.8ms
# Speed: 2.6ms preprocess, 8.8ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 8.0ms
# Speed: 2.3ms preprocess, 8.0ms inference, 0.8ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x640 (no detections), 10.6ms
# Speed: 3.2ms preprocess, 10.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Номерная табличка не найдена
#
#
# 0: 608x640 (no detections), 12.2ms
# Speed: 2.9ms preprocess, 12.2ms inference, 1.2ms postprocess per image at shape (1, 3, 608, 640)
#
# Номерная табличка не найдена
#
#
# 0: 416x640 (no detections), 12.7ms
# Speed: 2.1ms preprocess, 12.7ms inference, 2.2ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x640 (no detections), 13.1ms
# Speed: 3.1ms preprocess, 13.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 12.7ms
# Speed: 2.6ms preprocess, 12.7ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 14.9ms
# Speed: 2.7ms preprocess, 14.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 9.0ms
# Speed: 2.5ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 8.4ms
# Speed: 2.5ms preprocess, 8.4ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x544 (no detections), 15.1ms
# Speed: 2.9ms preprocess, 15.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 544)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 8.9ms
# Speed: 2.4ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 10.4ms
# Speed: 2.7ms preprocess, 10.4ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 14.0ms
# Speed: 2.4ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 384x640 15 cars, 14.3ms
# Speed: 7.6ms preprocess, 14.3ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.8ms
# Speed: 1.4ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 7.8ms
# Speed: 2.8ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 416x640 (no detections), 9.2ms
# Speed: 1.8ms preprocess, 9.2ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x640 (no detections), 7.3ms
# Speed: 2.2ms preprocess, 7.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# Номерная табличка не найдена
#
#
# 0: 608x640 (no detections), 7.9ms
# Speed: 2.1ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 608, 640)
#
# Номерная табличка не найдена
#
#
# 0: 416x640 (no detections), 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x640 (no detections), 7.3ms
# Speed: 2.2ms preprocess, 7.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.7ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 8.7ms
# Speed: 1.8ms preprocess, 8.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 7.2ms
# Speed: 1.8ms preprocess, 7.2ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 576x640 (no detections), 9.1ms
# Speed: 2.6ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x608 (no detections), 7.9ms
# Speed: 2.2ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 7.0ms
# Speed: 1.6ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 576x640 (no detections), 7.9ms
# Speed: 2.1ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 7.4ms
# Speed: 3.3ms preprocess, 7.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 384x640 15 cars, 10.3ms
# Speed: 4.3ms preprocess, 10.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 (no detections), 7.5ms
# Speed: 1.3ms preprocess, 7.5ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 7.8ms
# Speed: 1.8ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 384x640 (no detections), 7.0ms
# Speed: 1.4ms preprocess, 7.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# Номерная табличка не найдена
#
#
# 0: 608x640 (no detections), 8.0ms
# Speed: 2.1ms preprocess, 8.0ms inference, 0.7ms postprocess per image at shape (1, 3, 608, 640)
#
# Номерная табличка не найдена
#
#
# 0: 608x640 (no detections), 7.9ms
# Speed: 2.1ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 608, 640)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 6.8ms
# Speed: 1.6ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 608x640 (no detections), 9.2ms
# Speed: 2.5ms preprocess, 9.2ms inference, 0.8ms postprocess per image at shape (1, 3, 608, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 6.8ms
# Speed: 1.7ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 7.0ms
# Speed: 1.8ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 6.9ms
# Speed: 1.8ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 576x640 (no detections), 7.9ms
# Speed: 1.9ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x576 (no detections), 7.8ms
# Speed: 2.4ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 576)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 7.2ms
# Speed: 2.5ms preprocess, 7.2ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 576x640 (no detections), 7.9ms
# Speed: 1.9ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 8.8ms
# Speed: 1.9ms preprocess, 8.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 384x640 15 cars, 9.6ms
# Speed: 7.2ms preprocess, 9.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 (no detections), 7.2ms
# Speed: 1.4ms preprocess, 7.2ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 7.8ms
# Speed: 1.9ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 384x640 (no detections), 7.1ms
# Speed: 1.6ms preprocess, 7.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# Номерная табличка не найдена
#
#
# 0: 576x640 (no detections), 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x640 (no detections), 7.3ms
# Speed: 2.2ms preprocess, 7.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 6.7ms
# Speed: 1.6ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 608x640 (no detections), 8.2ms
# Speed: 3.1ms preprocess, 8.2ms inference, 0.7ms postprocess per image at shape (1, 3, 608, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 7.0ms
# Speed: 1.9ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 7.0ms
# Speed: 1.8ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x640 (no detections), 7.3ms
# Speed: 2.2ms preprocess, 7.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x608 (no detections), 7.9ms
# Speed: 2.1ms preprocess, 7.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 608)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 6.6ms
# Speed: 1.6ms preprocess, 6.6ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 576x640 (no detections), 8.0ms
# Speed: 1.9ms preprocess, 8.0ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 12.4ms
# Speed: 2.4ms preprocess, 12.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 384x640 17 cars, 15.2ms
# Speed: 4.7ms preprocess, 15.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 7.0ms
# Speed: 1.4ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 8.8ms
# Speed: 2.0ms preprocess, 8.8ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 384x640 (no detections), 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 7.8ms
# Speed: 2.0ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 608x640 (no detections), 8.0ms
# Speed: 2.4ms preprocess, 8.0ms inference, 0.7ms postprocess per image at shape (1, 3, 608, 640)
#
# Номерная табличка не найдена
#
#
# 0: 416x640 (no detections), 7.2ms
# Speed: 1.5ms preprocess, 7.2ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка не найдена
#
#
# 0: 608x640 (no detections), 7.9ms
# Speed: 2.1ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 608, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 6.8ms
# Speed: 1.8ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 8.9ms
# Speed: 2.7ms preprocess, 8.9ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 8.2ms
# Speed: 3.1ms preprocess, 8.2ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x640 (no detections), 7.3ms
# Speed: 2.1ms preprocess, 7.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x608 (no detections), 8.0ms
# Speed: 2.1ms preprocess, 8.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 11.0ms
# Speed: 2.4ms preprocess, 11.0ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 576x640 (no detections), 9.0ms
# Speed: 2.3ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 576, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 6.7ms
# Speed: 1.7ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x576 (no detections), 7.9ms
# Speed: 2.7ms preprocess, 7.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 576)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 384x640 16 cars, 9.0ms
# Speed: 3.9ms preprocess, 9.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 12.6ms
# Speed: 2.2ms preprocess, 12.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 9.6ms
# Speed: 2.7ms preprocess, 9.6ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
#
# 0: 576x640 1 License_Plate, 9.5ms
# Speed: 2.9ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 640)
#
# Номерная табличка найдена с координатами: (0, 11, 125, 105), уверенность: 0.279
#
#
# Текст не распознан
#
#
# 0: 640x640 (no detections), 7.4ms
# Speed: 2.1ms preprocess, 7.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# Номерная табличка не найдена
#
#
# 0: 448x640 (no detections), 6.8ms
# Speed: 1.6ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# Номерная табличка не найдена
#
#
# 0: 608x640 (no detections), 9.0ms
# Speed: 2.5ms preprocess, 9.0ms inference, 0.8ms postprocess per image at shape (1, 3, 608, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 7.8ms
# Speed: 1.9ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 6.7ms
# Speed: 1.8ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 576x640 (no detections), 7.9ms
# Speed: 1.9ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x640 (no detections), 7.3ms
# Speed: 2.1ms preprocess, 7.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x608 (no detections), 8.0ms
# Speed: 2.1ms preprocess, 8.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
#
# Номерная табличка не найдена
#
#
# 0: 416x640 (no detections), 8.5ms
# Speed: 1.7ms preprocess, 8.5ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# Номерная табличка не найдена
#
#
# 0: 544x640 (no detections), 8.7ms
# Speed: 2.2ms preprocess, 8.7ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 640)
#
# Номерная табличка не найдена
#
#
# 0: 480x640 (no detections), 7.7ms
# Speed: 2.6ms preprocess, 7.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Номерная табличка не найдена
#
#
# 0: 640x608 (no detections), 7.9ms
# Speed: 2.3ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
#
# Номерная табличка не найдена
#
#
# 0: 512x640 (no detections), 6.7ms
# Speed: 1.7ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# Номерная табличка не найдена
#
# Логи распознанных номеров сохранены по пути: /content/drive/MyDrive/Tracking/detected_plates_moscow.csv
# Видео с тепловой картой и номерами сохранено по пути: /content/drive/MyDrive/Tracking/tracked_video_moscow.mp4

# %%
# Отображение видео с трекингом
display_video(tracked_video_path)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## Результаты
#
# * [Видео 1: Дорога в Угличе](https://drive.google.com/file/d/1J_caJ6KrH6_tYpekPuTmqRTv7Nvuf3BN/view?usp=sharing)
#
#   * YOLOv8 успешно распознавала большинство автомобилей. Однако наблюдались проблемы с "скачущими" bounding boxes и идентификацией, особенно для машины с дополнительным грузом, которая была ошибочно определена как две машины.
#
#   * Подсчет пересечений контрольной линии сработал корректно для большинства автомобилей.
#
#   * Номерные таблички не были распознаны ни для одного автомобиля. Это связано с тем, что качество видео недостаточно для четкого выделения текста на табличках. (https://drive.google.com/file/d/1NjjX59p_fUuweM3VbHYNmk3LscK1F0b6/view?usp=sharing)
#
#   * Тепловая карта неплохо визуализировала плотность движения автомобилей.
#
# * [Видео 2: Дорога в Москве](https://drive.google.com/file/d/12pDzpEyCmBk11ec9l4xLDAkyoAzsCGZn/view?usp=sharing)
#
#   * YOLOv8 пропустила много автомобилей, особенно на участках с низкой освещенностью. Наблюдались проблемы с "скачущими" bounding boxes и идентификацией.
#
#   * Многие машины при пересечении контрольной линии не окрашивались в другой цвет, что указывает на ошибки в работе трекера.
#
#   * Как и в первом видео, номерные таблички не были распознаны ни для одного автомобиля. Человеческим взглядом также невозможно разглядеть номера на видео из-за низкого качества. (https://drive.google.com/file/d/1icXahcdaip8JwrxXLYDgRF_Ad50M86Hm/view?usp=sharing)
#
#   * Тепловая карта показала общую активность движения, но из-за пропусков в детекции автомобилей карта менее информативна.

# %% [markdown]
# ### Выводы
#
# * YOLOv8 показала приемлемые результаты на видео с более лучшим качеством (Углич), но на видео с низким качеством (Москва) производительность значительно ухудшилась. Взять модель YOLO11 не было возможности из-за ограниченных ресурсов.
#
# * Проблемы со "скачущими" bounding boxes и пропусками автомобилей требуют дальнейшей настройки модели и трекера.
#
# * Распознавание номеров оказалось невозможным из-за низкого качества видео.
# Для успешного распознавания номеров требуется видео с более высоким разрешением и четкостью.
#
# * Тепловая карта успешно визуализировала плотность движения, но ее точность зависит от качества детекции автомобилей.

# %% [markdown]
# ### Что можно улучшить
#
# * Использовать более качественные видео для анализа. Но, к сожалнеию, все камеры на geocam.ru либо не очень высокого качества, либо не работают.
#
# * Дополнительно настроить модель YOLOv8 и трекер BoT-SORT для улучшения стабильности детекции.
#
# * Применять другие методы повышения качества изображения перед распознаванием номерных табличек.
